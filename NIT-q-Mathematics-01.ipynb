# %% [markdown]
# <a href="https://shiroyasu.github.io/index.html">home</a> &#155;&#155; <a href="https://shiroyasu.github.io/teaching/index.html">Teaching</a> &#155;&#155;

# %% [markdown]
# # 「数学」 / Mathematics #

# %% [markdown]
# ## 第1回 偏微分(1) ##
# <span style="font-size: x-small; color: #808080; line-height: 135%;">【授業前】導関数の定義と記号 $\dfrac{dy}{dx}$ の意味についてテキストを用いて調べ, 理解できなかった事項をノートに記しておくこと.</span><br>
# <span style="font-size: x-small; color: #808080; line-height: 135%;">【授業後】２変数関数とその偏微分係数, 偏導関数について確認し, 授業中に解いた問題を解き直すことで知識の定着に努めること.</span>

# %% [markdown]
# ### 2変数関数のそのグラフ <span style="background-color:#bbc8e6 ; color: white ;">&nbsp;2.3[1]&nbsp;</span> <span style="background-color:#e79db0 ; color: black ;">&nbsp;134, 135, 136&nbsp;</span> ###

# %% [markdown]
# <b>関数 $f(x,y)$ のグラフ</b>とは, 「方程式 $z=f(x,y)$ を満たす空間内の点 $(x,y,z)$ の全体」である.

# %% [markdown]
# #### 例）$f(x,y)=\sin(xy)$ ####
#
# $x=-1, y=-\frac{\pi}{4}$ のとき, $z=f\left(-1,-\frac{\pi}{4}\right)=\frac{1}{\sqrt{2}}$ である.

# %%
JupyterImageResolution = 72;
Sin[(-1)*(-Pi/4)]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="27"></div>

# %% [markdown]
# よって, 点$(-1, -\pi/4, 1/\sqrt{2})$ は, $z=\sin(xy)$ のグラフ上の点である.

# %%
a=-1;
b=-Pi/4;
Show[
    Plot3D[Sin[x*y],{x,-2,2},{y,-2,2},PlotStyle->Opacity[0.05],Mesh->False],
    Graphics3D[{PointSize[0.01],Point[{a,b,Sin[a*b]}],Point[{a,b,0}]}],
    Graphics3D[{Dashed, Line[{{a,0,0},{a,b,0},{0,b,0}}],Line[{{a,b,0},{a,b,Sin[a*b]}}]}],
    Graphics3D[{Arrow[{{-2,0,0},{2,0,0}}],Arrow[{{0,-2,0},{0,2,0}}],Arrow[{{0,0,-2},{0,0,2}}]}]
]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="360"></div>

# %% [markdown]
# $z=\sin(xy)$ のグラフ上の点を他にも描いてみる.

# %%
Show[
    Graphics3D[Table[Point[{a,b,Sin[a*b]}],{a,-2,2,1/2},{b,-2,2,1/2}]]
]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="360"></div>

# %% [markdown]
# もう少し

# %%
Show[
    Graphics3D[Table[Point[{a,b,Sin[a*b]}],{a,-2,2,1/5},{b,-2,2,1/5}]]
]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="360"></div>

# %% [markdown]
# もう少し…

# %%
Show[
    Graphics3D[Table[Point[{a,b,Sin[a*b]}],{a,-2,2,1/10},{b,-2,2,1/10}]]
]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="360"></div>

# %% [markdown]
# このような点の全体は, 空間内の<b>曲面</b>をなす.

# %%
Plot3D[Sin[x*y],{x,-2,2},{y,-2,2}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="360"></div>

# %% [markdown]
# $f(x,y)$ の<a href="https://ja.wikipedia.org/wiki/%E7%AD%89%E9%AB%98%E7%B7%9A">等高線</a> とは, $f(x,y)=c$ を満たす点$(x,y)$の全体のこと.

# %% [markdown]
# 関数 $f(x,y)=\sin(xy)$ に対し, $\sin(xy)=\dfrac{1}{16}$ を満たす点$(x,y)$ の全体は以下のようになる.

# %%
ContourPlot[Sin[x*y]==1/16,{x,-2,2},{y,-2,2}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="360"></div>

# %% [markdown]
# 関数 $f(x,y)=\sin(xy)$ の等高線 $\sin(xy)=c$ を, いろいろな $c$ について描くと, 次のような等高線群が得られる.

# %%
ContourPlot[Sin[x*y],{x,-2,2},{y,-2,2}]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="360"></div>

# %% [markdown]
# ### 2変数関数の微分 <span style="background-color:#bbc8e6 ; color: white ;">&nbsp;2.4[1]&nbsp;</span> <span style="background-color:#e79db0 ; color: black ;">&nbsp;137, 138, 139&nbsp;</span> ###

# %% [markdown]
# - 2変数関数 $f(x,y)$ に対し, 一方の変数を定数とみて, 他方の変数について微分することを「<b>偏微分する</b>」という.
# - 偏微分した関数のことを<b>偏導関数</b>とう.
# - 『偏』は「かたより」ということ. 英語では "Partial derivative" または "Partial differentiation" という（「部分的な」微分）.
# - $\dfrac{\partial}{\partial x}$ は「$x$ の関数とみて偏微分せよ」という記号と解釈する. $\dfrac{d}{dx}$ との違いを理解すること.
# - 偏導関数を表す記号は「$\partial$」を使うものの他に, 微分する変数を関数記号の右下に書く流儀もある.

# %% [markdown]
# #### 関数 $f(x,y)=\sin(xy)$ を偏微分する. ####

# %%
D[Sin[x*y],x]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="70"></div>

# %%
D[Sin[x*y],y]
# Out:
# <div><img alt="Output" src="data:image/png;base64,..." width="70"></div>

# %% [markdown]
# 偏微分の計算においては, 微分の性質がそのまま適用できる.
#
# - $\left\{f(x)+g(x)\right\}'=f'(x)+g'(x)$
# - $k$ を定数とすると, $\left\{k\,f(x)\right\}'=k\,f'(x)$
# - 定値関数 $f(x)=k$ に対し, $f'(x)=(k)'=0$

# %% [markdown]
# - 積の微分の公式 $$\left\{f(x)\,g(x)\right\}'=f'(x)\,g(x)+f(x)\,g'(x)$$
# - 商の微分の公式 $$\left\{\dfrac{f(x)}{g(x)}\right\}'=\dfrac{f'(x)\,g(x)-f(x)\,g'(x)}{g(x)^2}$$
# - 合成関数の微分の公式 $$\left\{f(g(x))\right\}'=f'(g(x))\cdot g'(x)$$

# %% [markdown]
# - 初等関数の微分の公式
# $$\left(x^\alpha\right)'=\alpha\,x^{\alpha-1}$$
# など…
